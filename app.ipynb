# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
df = pd.read_excel('BC-PS-BC-Hari-Bekerja-10072023.xlsx', sheet_name="Table 1")

# %%
#df['Nombor Tren'] == "Kuala Lumpur"
departure = "Kuala Lumpur"
destination = "Pulau Sebang"

x = None
y = None
for index, row in df.iterrows():
    if row['Nombor Tren'] == "Pulau Sebang":
        x = index
    if row['Nombor Tren'] == "Kuala Lumpur":
        y = index

if ( y > x ) :
    print ( "X : ", x ,"Y : ", y , " Read from Table 2") 
else :
    print ( "X : ", x ,"Y : ", y , " Read from Table 1")
# Out:
# X :  26 Y :  7  Read from Table 1

# %%
len(df)
# Out:
# 27

# %%
df
# Out:
#              Nombor Tren  2003  2007  2011   2013   2015  2017   2019   2021  \
# 0             Batu Caves   NaN  6:00  6:40   7:18   7:55  8:25   9:00   9:32
# 1            Taman Wahyu   NaN  6:04  6:44   7:22   7:59  8:29   9:04   9:36
# 2           Kampung Batu   NaN  6:07  6:47   7:25   8:02  8:32   9:07   9:39
# 3         Batu Kentonmen   NaN  6:09  6:49   7:27   8:04  8:34   9:09   9:41
# 4                 Sentul  5:12  6:13  6:53   7:31   8:08  8:38   9:13   9:45
# 5                  Putra  5:18  6:19  6:59   7:37   8:14  8:44   9:19   9:51
# 6            Bank Negara  5:21  6:22  7:02   7:40   8:17  8:47   9:22   9:54
# 7           Kuala Lumpur  5:26  6:27  7:07   7:50   8:22  8:57   9:29   9:59
# 8             KL Sentral  5:32  6:33  7:18   7:57   8:31  9:03   9:35  10:05
# 9              MidValley  5:39  6:40  7:35   8:05   8:38  9:10   9:42  10:18
# 10               Seputeh  5:41  6:42  7:37   8:07   8:40  9:12   9:44  10:20
# ...

# %%
depart_destination = [ "Kuala Lumpur", "Pulau Sebang"]
chk_route = df['Nombor Tren'].isin(depart_destination)

chk_route
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26     True
# Name: Nombor Tren, dtype: bool

# %%
depart_destination = [ "Kuala Lumpur", "Pulau Sebang"]
train_scedule = df.loc[df['Nombor Tren'].isin(depart_destination)]


print("Shape >>", train_scedule.shape)
print("Length >>",len(train_scedule))

train_scedule
# Out:
# Shape >> (2, 34)
# Length >> 2
#      Nombor Tren  2003  2007  2011   2013  2015  2017  2019  2021   2023  ...  \
# 7   Kuala Lumpur  5:26  6:27  7:07   7:50  8:22  8:57  9:29  9:59  10:30  ...
# 26  Pulau Sebang  7:56   NaN   NaN  10:19   NaN   NaN   NaN   NaN    NaN  ...
#
#      2055 Unnamed: 25 Unnamed: 26   2057 Unnamed: 28 Unnamed: 29   2059  \
# 7   17:58         NaN         NaN  18:32         NaN         NaN  19:03
# 26  20:30         NaN         NaN  21:11         NaN         NaN    NaN
#
#      2061   2065   2071
# 7   20:27  21:35  22:37
# 26    NaN    NaN    NaN
#
# [2 rows x 34 columns]

# %%
masa = datetime.now().time().strftime("%H:%M")
now = datetime.strptime((masa), '%H:%M').time() 

# check destination route if nan, drop col
idx = 0
column_to_be_drop = []
for y in train_scedule:
    #print(train_scedule.iat[1,idx])
    try:
        #print (datetime.strptime((train_scedule.iat[1,idx]), '%H:%M').time() )
         if (datetime.strptime((train_scedule.iat[1,idx]), '%H:%M').time() ) < now:
             #print (datetime.strptime((train_scedule.iat[1,idx]), '%H:%M').time() )
             column_to_be_drop.append(idx) # drop
         else:
             print (datetime.strptime((train_scedule.iat[1,idx]), '%H:%M').time() )
    except:
        #print("drop col > ", idx , " <",train_scedule.iat[1,idx])
        column_to_be_drop.append(idx)
        
    
    idx = idx + 1
    #del train_scedule[idx]
# Out:
# 16:59:00
# 19:13:00
# 20:04:00
# 20:16:00
# 20:30:00
# 21:11:00

# %%
train_scedule.drop(train_scedule.columns[column_to_be_drop], axis=1, inplace=True)

train_scedule
# Out:
# /var/folders/lr/l_srfq3173b983lxd680cs6w0000gn/T/ipykernel_1762/1140766502.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_scedule.drop(train_scedule.columns[column_to_be_drop], axis=1, inplace=True)
#     2003   2013   2037   2049   2053   2603   2055   2057
# 7   5:26   7:50  14:32  16:32  17:42  17:54  17:58  18:32
# 26  7:56  10:19  16:59  19:13  20:04  20:16  20:30  21:11

# %%
masa = datetime.now().time().strftime("%H:%M")
now = datetime.strptime((masa), '%H:%M').time() 


print("current time = ", now)
# Out:
# current time =  12:22:00

# %%
#display upcoming schedule only
